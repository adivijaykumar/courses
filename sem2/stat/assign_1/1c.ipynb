# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
trace = []
space_evals = []
for i in range(1000000):
    a, b, c = np.random.uniform(0,1,3)
    mat = (np.matrix([[a,b],[b,c]]))
    trace.append(np.trace(mat))
    e1, e2 = np.linalg.eigvalsh(mat)
    space_evals.append(np.abs(e1-e2))

# %%
plt.hist(trace)
plt.figure()

plt.hist(space_evals)
# Out:
# (array([ 35398.,  91323., 125245., 135558., 126754., 119246., 116811.,
#         114875., 114159.,  20631.]),
#  array([7.99406063e-04, 2.23193300e-01, 4.45587193e-01, 6.67981087e-01,
#         8.90374981e-01, 1.11276887e+00, 1.33516277e+00, 1.55755666e+00,
#         1.77995056e+00, 2.00234445e+00, 2.22473834e+00]),
#  <a list of 10 Patch objects>)
